# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("./treated_surface.csv")
data.head()
# Out:
#           id                                           title bathrooms  \
# 0  126619903    Stanza singola viale Monte Ceneri 29, Milano         1
# 1  126175263  Stanza singola via Pasquale Fornari 18, Milano         1
# 2  127213847         Stanza singola viale Certosa 20, Milano         1
# 3  125127515         Stanza singola via Caianello 23, Milano         2
# 4  123586715       Stanza singola via Privata Deruta, Milano         1
#
#          heating                                           features  \
# 0        Assente  balcone, cucina, bagno in comune, parquet, armadi
# 1        Assente  cucina, lavatrice, bagno in comune, attacco te...
# 2        Assente  balcone, cucina, lavatrice, bagno in comune, a...
# 3        Assente  cucina, lavatrice, bagno in comune, attacco te...
# 4  Centralizzato                                           arredato
#
#                 address                               macrozone  \
# ...

# %%
X= pd.DataFrame(data["features"].unique())
X.head()
