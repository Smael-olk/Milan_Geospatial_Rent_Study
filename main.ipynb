# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("./milan_rent_clean.xlsx")
data.head()
# Out:
#           id                                           title rooms bathrooms  \
# 0  126619903    Stanza singola viale Monte Ceneri 29, Milano     2         1
# 1  126175263  Stanza singola via Pasquale Fornari 18, Milano     4         1
# 2  127213847         Stanza singola viale Certosa 20, Milano     5         1
# 3  125127515         Stanza singola via Caianello 23, Milano     5         2
# 4  123586715       Stanza singola via Privata Deruta, Milano     1         1
#
#   surface floor        heating  \
# 0   19 m²    5°        Assente
# 1   86 m²    3°        Assente
# 2  100 m²    7°        Assente
# 3   90 m²    1°        Assente
# 4   16 m²   NaN  Centralizzato
#
#                                             features               address  \
# 0  balcone, cucina, bagno in comune, parquet, armadi    Viale Monte Ceneri
# 1  cucina, lavatrice, bagno in comune, attacco te...  Via Pasquale Fornari
# 2  balcone, cucina, lavatrice, bagno in comune, a...         Viale Certosa
# 3  cucina, lavatrice, bagno in comune, attacco te...         Via Caianello
# 4                                           arredato    Via Privata Deruta
#
#                                 macrozone             microzone  latitude  \
# 0  Uptown, Cascina Merlata, Viale Certosa  Ghisolfa - Mac Mahon   45.4926
# 1                     Bande Nere, Inganni               Gambara   45.4632
# 2  Uptown, Cascina Merlata, Viale Certosa  Ghisolfa - Mac Mahon   45.4898
# 3                          Affori, Bovisa               Dergano   45.5001
# 4                         Udine, Lambrate                 Udine   45.4929
#
#    longitude  price_n  surface_n  rooms_n  price_sqm
# 0     9.1559      500       19.0      2.0  26.315789
# 1     9.1436      550       86.0      4.0   6.395349
# 2     9.1527      570      100.0      5.0   5.700000
# 3     9.1722      490       90.0      5.0   5.444444
# 4     9.2393      400       16.0      1.0  25.000000

# %%
plt.hist(data["surface_n"])
# Out:
# (array([3237.,  149.,  312.,  562.,  468.,  291.,  236.,   68.,   22.,
#           17.]),
#  array([  6. ,  25.9,  45.8,  65.7,  85.6, 105.5, 125.4, 145.3, 165.2,
#         185.1, 205. ]),
#  <BarContainer object of 10 artists>)

# %%
total_listings = len(data["surface_n"])
print("Number of Listings :", total_listings)
S_lim = 150
count_condition = (data["surface_n"]>S_lim).sum() 
print("Count of listings such that bigger than",S_lim,":", count_condition )
print("Percentage: %.2f" %   (count_condition / total_listings * 100))
data[data["surface_n"]>S_lim]

# %%
data[data["rooms_n"]==5]
# Out:
#              id                                              title  \
# 2     127213847            Stanza singola viale Certosa 20, Milano
# 3     125127515            Stanza singola via Caianello 23, Milano
# 12    125866583     Stanza singola via Raffaello Giolli 28, Milano
# 15    127533904        Stanza singola via Salvatore Rosa 2, Milano
# 25    115244887         Stanza singola via Jan Sibelius 24, Milano
# ...         ...                                                ...
# 5339  127570282  Stanza in affitto in appartamento via Nino Oxi...
# 5340  127490538  Stanza in affitto in appartamento via Pordenon...
# 5341  127355819  Stanza in affitto in appartamento via Lipari, ...
# 5342  127355413  Stanza in affitto in appartamento piazza Sant'...
# 5343  127414875  Stanza in affitto in appartamento via Caradoss...
#
#      price_value price_formatted rooms bathrooms surface              floor  \
# 2       € 570.00      € 570/mese     5         1  100 m²                 7°
# 3       € 490.00      € 490/mese     5         2   90 m²                 1°
# 12      € 580.00      € 580/mese     5         2   11 m²                 8°
# 15      € 450.00      € 450/mese    5+         2   14 m²        Piano terra
# 25      € 550.00      € 550/mese     5         2   18 m²                 8°
# ...          ...             ...   ...       ...     ...                ...
# 5339    € 845.00      € 845/mese    5+         2  140 m²                 3°
# 5340    € 870.00      € 870/mese     5         2   15 m²  2°, con ascensore
# 5341    € 865.00      € 865/mese     5         2  126 m²                 1°
# 5342    € 875.00      € 875/mese    5+         2  157 m²  5°, con ascensore
# 5343    € 995.00      € 995/mese     5         2  113 m²                 4°
#
#        heating                                           features  ...  \
# 2      Assente  balcone, cucina, lavatrice, bagno in comune, a...  ...
# 3      Assente  cucina, lavatrice, bagno in comune, attacco te...  ...
# 12     Assente  ripostiglio, giardino, balcone, cucina, connes...  ...
# 15     Assente  ripostiglio, cucina, connessione ad internet, ...  ...
# 25     Assente  giardino, balcone, connessione ad internet, la...  ...
# ...        ...                                                ...  ...
# 5339  Autonomo  fibra ottica, porta blindata, esposizione este...  ...
# 5340  Autonomo  fibra ottica, porta blindata, esposizione este...  ...
# 5341  Autonomo  fibra ottica, porta blindata, esposizione este...  ...
# 5342  Autonomo  fibra ottica, porta blindata, esposizione este...  ...
# 5343  Autonomo  fibra ottica, porta blindata, esposizione este...  ...
#
#      longitude              agency_name  phone_number  photo_count  \
# 2      9.15270             Welcome Home  02 8974 7773           20
# 3      9.17220             Welcome Home  02 8974 7773           17
# 12     9.21110       Chance immobiliare  02 8127 3297           19
# 15     9.14280          Immobiliare DsT  039 974 7101           17
# 25     9.20810        Magic Real Estate  02 8974 7532           11
# ...        ...                      ...           ...          ...
# 5339   9.21173  Spacest.com by Roomless  02 8974 1955           35
# 5340   9.23447  Spacest.com by Roomless  02 8974 1955           19
# 5341   9.16101  Spacest.com by Roomless  02 8974 1955           29
# 5342   9.17012  Spacest.com by Roomless  02 8974 1955           25
# 5343   9.17255  Spacest.com by Roomless  02 8974 1955           21
#
#                                                 url  \
# 2     https://www.immobiliare.it/annunci/127213847/
# 3     https://www.immobiliare.it/annunci/125127515/
# 12    https://www.immobiliare.it/annunci/125866583/
# 15    https://www.immobiliare.it/annunci/127533904/
# 25    https://www.immobiliare.it/annunci/115244887/
# ...                                             ...
# 5339  https://www.immobiliare.it/annunci/127570282/
# 5340  https://www.immobiliare.it/annunci/127490538/
# 5341  https://www.immobiliare.it/annunci/127355819/
# 5342  https://www.immobiliare.it/annunci/127355413/
# 5343  https://www.immobiliare.it/annunci/127414875/
#
#                                             description price_n  surface_n  \
# 2     CALL US WE SPEAK: ENGLISH - SPANISH - POURTOGU...     570      100.0
# 3     PROMO SENZA SOESE DI AGENZIA!  CALL US WE SPEA...     490       90.0
# 12                                                  NaN     580       11.0
# 15                                                  NaN     450       14.0
# 25                                                  NaN     550       18.0
# ...                                                 ...     ...        ...
# 5339                                                NaN     845      140.0
# 5340                                                NaN     870       15.0
# 5341                                                NaN     865      126.0
# 5342                                                NaN     875      157.0
# 5343                                                NaN     995      113.0
#
#      rooms_n  price_sqm
# 2        5.0   5.700000
# 3        5.0   5.444444
# 12       5.0  52.727273
# 15       5.0  32.142857
# 25       5.0  30.555556
# ...      ...        ...
# 5339     5.0   6.035714
# 5340     5.0  58.000000
# 5341     5.0   6.865079
# 5342     5.0   5.573248
# 5343     5.0   8.805310
#
# [1172 rows x 24 columns]
